# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import datetime
import os

# %%
df= pd.read_csv('E:\\CSV\student.csv')

# %%
df.count()
# Out:
# id        35
# name      35
# class     35
# mark      35
# gender    35
# dtype: int64

# %%
df1=df.replace('male',0)
df2=df1.replace('female',1)

# %%
df2.dtypes
# Out:
# id         int64
# name      object
# class     object
# mark       int64
# gender     int64
# dtype: object

# %%
df2.shape
# Out:
# (35, 5)

# %%
df2[0:35]
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four    75       1
# 1    2     Max Ruin  Three    85       0
# 2    3       Arnold  Three    55       0
# 3    4   Krish Star   Four    60       1
# 4    5    John Mike   Four    60       1
# 5    6    Alex John   Four    55       0
# 6    7  My John Rob  Fifth    78       0
# 7    8       Asruid   Five    85       0
# 8    9      Tes Qry    Six    78       0
# 9   10     Big John   Four    55       1
# 10  11       Ronald    Six    89       1
# 11  12        Recky    Six    94       1
# 12  13          Kty  Seven    88       1
# 13  14         Bigy  Seven    88       1
# 14  15     Tade Row   Four    88       0
# 15  16        Gimmy   Four    88       0
# 16  17        Tumyu    Six    54       0
# 17  18        Honny   Five    75       0
# 18  19        Tinny   Nine    18       0
# 19  20       Jackly   Nine    65       1
# 20  21   Babby John   Four    69       1
# 21  22       Reggid  Seven    55       1
# ...

# %%
df2.groupby(['gender'])['mark'].mean()
# Out:
# gender
# 0    71.944444
# 1    77.529412
# Name: mark, dtype: float64

# %%
df3 = df2.replace({'class' : { 'Three' : 3, 'Four' : 4, 'Fifth' : 5, 'Five': 5, 'Six' : 6, 'Seven' : 7, 'Eight' : 8, 'Nine' : 9}})

# %%
df3[0:35]
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo      4    75       1
# 1    2     Max Ruin      3    85       0
# 2    3       Arnold      3    55       0
# 3    4   Krish Star      4    60       1
# 4    5    John Mike      4    60       1
# 5    6    Alex John      4    55       0
# 6    7  My John Rob      5    78       0
# 7    8       Asruid      5    85       0
# 8    9      Tes Qry      6    78       0
# 9   10     Big John      4    55       1
# 10  11       Ronald      6    89       1
# 11  12        Recky      6    94       1
# 12  13          Kty      7    88       1
# 13  14         Bigy      7    88       1
# 14  15     Tade Row      4    88       0
# 15  16        Gimmy      4    88       0
# 16  17        Tumyu      6    54       0
# 17  18        Honny      5    75       0
# 18  19        Tinny      9    18       0
# 19  20       Jackly      9    65       1
# 20  21   Babby John      4    69       1
# 21  22       Reggid      7    55       1
# ...

# %%
df3.sort_values('class')
# Out:
#     id         name  class  mark  gender
# 1    2     Max Ruin      3    85       0
# 2    3       Arnold      3    55       0
# 26  27     Big Nose      3    81       1
# 0    1     John Deo      4    75       1
# 3    4   Krish Star      4    60       1
# 4    5    John Mike      4    60       1
# 5    6    Alex John      4    55       0
# 30  31  Marry Toeey      4    88       0
# 20  21   Babby John      4    69       1
# 9   10     Big John      4    55       1
# 15  16        Gimmy      4    88       0
# 14  15     Tade Row      4    88       0
# 17  18        Honny      5    75       0
# 6    7  My John Rob      5    78       0
# 7    8       Asruid      5    85       0
# 34  35   Rows Noump      6    88       1
# 11  12        Recky      6    94       1
# 10  11       Ronald      6    89       1
# 16  17        Tumyu      6    54       0
# 32  33    Kenn Rein      6    96       1
# 8    9      Tes Qry      6    78       0
# 29  30    Reppy Red      6    79       1
# ...

# %%
avg = df3.groupby(['class'])['mark'].mean()

# %%
avg
# Out:
# class
# 3    73.666667
# 4    70.888889
# 5    79.333333
# 6    82.571429
# 7    77.600000
# 8    79.000000
# 9    41.500000
# Name: mark, dtype: float64

# %%
plt.bar(avg.index, avg)
# Out:
# <BarContainer object of 7 artists>

# %%
avg2= df.groupby(['gender'])['mark'].mean()

# %%
plt.bar(avg2.index,avg2)
# Out:
# <BarContainer object of 2 artists>
