# %%
import pandas as pd
import numpy as np
import seaborn as sns
import pandasql as ps

# %%
df = pd.read_csv('E:\\CSV\gdp_csv.csv')

# %%
df.head()
# Out:
#   Country Name Country Code  Year         Value
# 0   Arab World          ARB  1968  2.576068e+10
# 1   Arab World          ARB  1969  2.843420e+10
# 2   Arab World          ARB  1970  3.138550e+10
# 3   Arab World          ARB  1971  3.642691e+10
# 4   Arab World          ARB  1972  4.331606e+10

# %%
df.groupby("Country Name")

# %%
from pandasql import sqldf

# %%
df.shape
# Out:
# (11507, 4)

# %%
arabgdp = df.rename(columns={'Country Name': 'CN', 'Value': 'GDP in T$'})

# %%
query_df= arabgdp.query("CN == 'Arab World'")

# %%
print(query_df)
# Out:
#             CN Country Code  Year     GDP in T$
# 0   Arab World          ARB  1968  2.576068e+10
# 1   Arab World          ARB  1969  2.843420e+10
# 2   Arab World          ARB  1970  3.138550e+10
# 3   Arab World          ARB  1971  3.642691e+10
# 4   Arab World          ARB  1972  4.331606e+10
# 5   Arab World          ARB  1973  5.501839e+10
# 6   Arab World          ARB  1974  1.051458e+11
# 7   Arab World          ARB  1975  1.163370e+11
# 8   Arab World          ARB  1976  1.448462e+11
# 9   Arab World          ARB  1977  1.673083e+11
# 10  Arab World          ARB  1978  1.835555e+11
# 11  Arab World          ARB  1979  2.486462e+11
# 12  Arab World          ARB  1980  3.381775e+11
# 13  Arab World          ARB  1981  3.485928e+11
# 14  Arab World          ARB  1982  3.243288e+11
# 15  Arab World          ARB  1983  3.039625e+11
# 16  Arab World          ARB  1984  3.079408e+11
# 17  Arab World          ARB  1985  3.038936e+11
# 18  Arab World          ARB  1986  2.890292e+11
# ...

# %%
query_df.plot.line(x='Year', y='GDP in T$')
# Out:
# <AxesSubplot: xlabel='Year'>

# %%
query_df_2 = arabgdp.query("CN == 'Central Europe and the Baltics'")
query_df_3 = arabgdp.query("CN == 'Poland'")
query_df_4 = arabgdp.query("CN == 'Belgium'")
query_df_5 = arabgdp.query("CN == 'Argentina'")
query_df_6 = arabgdp.query("CN == 'Norway'")

# %%
print(query_df_2)
# Out:
#                                  CN Country Code  Year     GDP in T$
# 106  Central Europe and the Baltics          CEB  1990  2.563911e+11
# 107  Central Europe and the Baltics          CEB  1991  2.428449e+11
# 108  Central Europe and the Baltics          CEB  1992  2.600698e+11
# 109  Central Europe and the Baltics          CEB  1993  2.741925e+11
# 110  Central Europe and the Baltics          CEB  1994  3.110164e+11
# 111  Central Europe and the Baltics          CEB  1995  3.864839e+11
# 112  Central Europe and the Baltics          CEB  1996  4.129620e+11
# 113  Central Europe and the Baltics          CEB  1997  4.091779e+11
# 114  Central Europe and the Baltics          CEB  1998  4.476750e+11
# 115  Central Europe and the Baltics          CEB  1999  4.341587e+11
# 116  Central Europe and the Baltics          CEB  2000  4.278264e+11
# 117  Central Europe and the Baltics          CEB  2001  4.684343e+11
# 118  Central Europe and the Baltics          CEB  2002  5.275158e+11
# ...

# %%
query_df_2.plot.line(x='Year', y='GDP in T$')
# Out:
# <AxesSubplot: xlabel='Year'>

# %%
ax = query_df.plot(x='Year', y='GDP in T$')
query_df_2.plot(ax=ax,x='Year',y='GDP in T$')
query_df_3.plot(ax=ax,x='Year', y='GDP in T$')
query_df_4.plot(ax=ax,x='Year', y='GDP in T$')
query_df_5.plot(ax=ax,x='Year', y='GDP in T$')
ax.set_xlabel("Year")
ax.set_ylabel("GDP in T$")
ax.legend(["Arab World","Central Europe & Baltics","Poland","Belgium","Argentina"])

# %%
ax = query_df_3.plot(x='Year', y='GDP in T$')
query_df_4.plot(ax=ax,x='Year', y='GDP in T$')
query_df_5.plot(ax=ax,x='Year', y='GDP in T$')
query_df_6.plot(ax=ax,x='Year', y='GDP in T$')
ax.set_xlabel("Year")
ax.set_ylabel("GDP in 100B $")
ax.legend(["Poland","Belgium","Argentina","Norway"])
